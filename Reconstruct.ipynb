# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from PIL import Image
import glob


image = Image.new('RGB', (4096,4096))
path = '/content/drive/MyDrive/flood_mapping/NEW/2021/EVOIA/PREDICTIONS/*.png'
images = glob.glob(path)
row = 0
col = 0
for idx,img in enumerate(images):
  if idx==0:
    idx=1
  if idx %16 == 0:
    row = row + 1
    col = 0  
  im = Image.open(img)
  image.paste(im,(col*256,row*256))
  col = col + 1

# %%
15%16
# Out:
# 15

# %%
import numpy as np
import matplotlib.pyplot as plt

test = np.asarray(image)
plt.figure(figsize = (15,15))
plt.imshow(test)
