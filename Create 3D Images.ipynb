# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from PIL import Image
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
import glob

# %%
S2after = '/content/drive/MyDrive/FORTH/OmbriaS2/train/AFTER/*.png'
S2before = '/content/drive/MyDrive/FORTH/OmbriaS2/train/BEFORE/*.png'

# %%
imageBefore = glob.glob(S2before)
imageAfter = glob.glob(S2after)
imBefore = np.array(Image.open(imageBefore[0]))
imAfter = np.array(Image.open(imageAfter[0]))
img = np.concatenate((imBefore, imAfter), axis=2)
im = Image.fromarray(img)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in fromarray(obj, mode)
#    2713         try:
# -> 2714             mode, rawmode = _fromarray_typemap[typekey]
#    2715         except KeyError:
#
# KeyError: ((1, 1, 6), '|u1')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-23f4a2b76775> in <module>()
#       4 imAfter = np.array(Image.open(imageAfter[0]))
#       5 img = np.concatenate((imBefore, imAfter), axis=2)
# ----> 6 im = Image.fromarray(img)
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in fromarray(obj, mode)
#    2714             mode, rawmode = _fromarray_typemap[typekey]
#    2715         except KeyError:
# ...

# %%
imageBefore = glob.glob(S2before)
imageAfter = glob.glob(S2after)
for i in range(len(imagesAfter)):
  imBefore = np.array(Image.open(imageBefore[i]))
  imAfter = np.array(Image.open(imageAfter[i]))
  img = np.concatenate((imBefore, imAfter), axis=2)
  im = Image.fromarray(img) 
  im.save(image)

# %%
S2afterTest = '/content/drive/MyDrive/NoAfter/OmbriaS2/test/AFTER/*.png'

# %%
images = glob.glob(S2afterTest)
for image in images:
  im = np.array(Image.open(image))
  img = im*0
  im = Image.fromarray(img) 
  im.save(image)

# %%
S1afterTrain = '/content/drive/MyDrive/NoAfter/OmbriaS1/train/AFTER/*.png'
images = glob.glob(S1afterTrain)
for image in images:
  im = np.array(Image.open(image))
  img = im*0
  im = Image.fromarray(img) 
  im.save(image)

# %%
S1afterTest = '/content/drive/MyDrive/NoAfter/OmbriaS1/test/AFTER/*.png'
images = glob.glob(S1afterTest)
for image in images:
  im = np.array(Image.open(image))
  img = im*0
  im = Image.fromarray(img) 
  im.save(image)
